# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_paths = [f"log_res34_aug_fold_{i}.csv" for i in range(5)]
file_paths
# Out:
# ['log_res34_aug_fold_0.csv',
#  'log_res34_aug_fold_1.csv',
#  'log_res34_aug_fold_2.csv',
#  'log_res34_aug_fold_3.csv',
#  'log_res34_aug_fold_4.csv']

# %%
from utils import plot_metrics_from_files
plot_metrics_from_files(file_paths)
